# %% [markdown]
# Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# Data Collection

# %%
df = pd.read_csv('Dataset/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
# Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# Categorical Features:
#
# - Sex
#
# - Smoker
#
# - Region

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Distribution of age value
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['age'])
plt.title('Age Distribution')
plt.show()
# Out:
# /tmp/ipykernel_9167/105158841.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
# Gender column
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=df)
plt.title('Sex Distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
# BMI distribution
plt.figure(figsize=(6,6))
sns.distplot(df['bmi'])
plt.title('BMI')
plt.show()
# Out:
# /tmp/ipykernel_9167/1563167878.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])

# %% [markdown]
# Normal BMI Range --> 18.5 to 24.9

# %%
# Children column
plt.figure(figsize=(6,6))
sns.countplot(x='children', data=df)
plt.title('Children')
plt.show()

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
# Smoker 
plt.figure(figsize=(6,6))
sns.countplot(x='smoker', data=df)
plt.title('Smoker')
plt.show()

# %%
# Regional Column
plt.figure(figsize=(6,6))
sns.countplot(x='region', data=df)
plt.title('region')
plt.show()

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['charges'])
plt.title('Charge Distribtuion')
plt.show()
# Out:
# /tmp/ipykernel_9167/2244356161.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['charges'])

# %% [markdown]
# Data Pre-Processing

# %% [markdown]
# Import Categorical features

# %%
# Encoding sex column
df.replace({'sex': {'male': 0, 'female': 1}}, inplace=True)

# Encoding smoker
df.replace({'smoker': {'yes': 0, 'no': 1}}, inplace=True)

# Region encoding
df.replace({'region': {'southeast': 0, 'southwest': 1, 'northeast': 2, 'northwest': 3}}, inplace=True)

df = df.infer_objects(copy=False)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       0       1  16884.92400
# 1   18    0  33.770         1       1       0   1725.55230
# 2   28    0  33.000         3       1       0   4449.46200
# 3   33    0  22.705         0       1       3  21984.47061
# 4   32    0  28.880         0       1       3   3866.85520

# %% [markdown]
# Splitting features and Target

# %%
X = df.drop('charges', axis=1)
Y = df['charges']

# %% [markdown]
# Splitting the data to Train and Test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %% [markdown]
# Model:
#
# Linear Regression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Evaluation

# %%
train_prediction = lin_reg.predict(X_train)

# %%
# R squared Value
r2_train = metrics.r2_score(Y_train, train_prediction)
print("R2 Score: ", r2_train)
# Out:
# R2 Score:  0.751505643411174

# %%
test_prediction = lin_reg.predict(X_test)

# %%
# on Test data
r2_test = metrics.r2_score(Y_test, test_prediction)
print("R2 Score: ", r2_test)
# Out:
# R2 Score:  0.7447273869684077

# %% [markdown]
# Predictive system

# %%
input_data = (31, 1, 25.74, 0, 1, 0)

# changing input data to numpy array
input_data_as_np_array = np.asarray(input_data)

# Reshaping the array
input_data_reshaped = input_data_as_np_array.reshape( 1, -1)

prediction = lin_reg.predict(input_data_reshaped)
print(prediction)

print('The Insurance cost is USD ', prediction[0])
# Out:
# [3760.0805765]
# /home/mithranes/Documents/old/Machine Learning/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
